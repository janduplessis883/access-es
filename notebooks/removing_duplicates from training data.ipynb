# %%
import pandas as pd

# %%
data5 = pd.read_csv('/Users/janduplessis/Library/CloudStorage/OneDrive-NHS/python-data/ACCESS BI/train_5_old.csv')
data6 = pd.read_csv('/Users/janduplessis/Library/CloudStorage/OneDrive-NHS/python-data/ACCESS BI/train_6_old.csv')

# %%
data = pd.concat([data5, data6], axis=0, ignore_index=True)

# %%
data
# Out:
#       Appointment date Appointment status             Clinician  \
# 0            03-Apr-23           Finished  HUSSEIN, Shuman (Dr)
# 1            03-Apr-23           Finished  HUSSEIN, Shuman (Dr)
# 2            03-Apr-23           Finished  HUSSEIN, Shuman (Dr)
# 3            03-Apr-23           Finished  HUSSEIN, Shuman (Dr)
# 4            03-Apr-23           Finished  HUSSEIN, Shuman (Dr)
# ...                ...                ...                   ...
# 45946        28-Mar-24           Finished        AMBULAI, Lahai
# 45947        28-Mar-24           Finished        AMBULAI, Lahai
# 45948        28-Mar-24           Finished        AMBULAI, Lahai
# 45949        28-Mar-24           Finished        AMBULAI, Lahai
# 45950        28-Mar-24           Finished        AMBULAI, Lahai
#
#                  Rota type  Patient ID  Patient Count
# 0         Stanhope Mews GP    49850099              1
# 1         Stanhope Mews GP    49833145              1
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(4026)

# %%
new = data.drop_duplicates(keep='first')

# %%
new[:25000].to_csv('/Users/janduplessis/Library/CloudStorage/OneDrive-NHS/python-data/ACCESS BI/train_5.csv', index=False)

# %%
new[25001:].to_csv('/Users/janduplessis/Library/CloudStorage/OneDrive-NHS/python-data/ACCESS BI/train_6.csv', index=False)
